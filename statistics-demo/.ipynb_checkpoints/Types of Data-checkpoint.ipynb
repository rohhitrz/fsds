# %% [markdown]
# # Data Creation of Nominal Column named "colors"

# %%
import numpy as np
import pandas as pd

np.random.seed(0) # seed will always create the same sample
num_samples=1000

colors=["Red","Green","Blue","Yellow", "grey","brown"]

nominal_data=np.random.choice(colors, num_samples)
# nominal_data
# Out:
# array(['grey', 'brown', 'Red', 'Yellow', 'Yellow', 'Yellow', 'Green',
#        'Yellow', 'brown', 'Blue', 'grey', 'Red', 'Red', 'grey', 'Blue',
#        'Green', 'Red', 'Green', 'brown', 'Green', 'brown', 'Red', 'Green',
#        'grey', 'Yellow', 'Red', 'Yellow', 'brown', 'Red', 'Blue',
#        'Yellow', 'Red', 'Green', 'Yellow', 'brown', 'Yellow', 'Yellow',
#        'Red', 'Green', 'Green', 'Green', 'Red', 'Blue', 'grey', 'Yellow',
#        'Yellow', 'Blue', 'grey', 'Blue', 'Red', 'Red', 'grey', 'brown',
#        'brown', 'Red', 'grey', 'Green', 'grey', 'Green', 'Blue', 'Blue',
#        'Red', 'Green', 'Green', 'Green', 'Green', 'Yellow', 'Yellow',
#        'Blue', 'Yellow', 'Red', 'Yellow', 'brown', 'grey', 'Green',
#        'Blue', 'grey', 'Yellow', 'grey', 'grey', 'grey', 'Yellow', 'grey',
#        'grey', 'grey', 'Red', 'grey', 'Yellow', 'Blue', 'brown', 'brown',
#        'brown', 'Red', 'Green', 'brown', 'Green', 'Yellow', 'Red',
#        'brown', 'Red', 'Green', 'Blue', 'grey', 'Blue', 'Red', 'brown',
#        'Yellow', 'Blue', 'Blue', 'brown', 'Red', 'brown', 'Green', 'Red',
#        'Blue', 'Blue', 'Yellow', 'Blue', 'Yellow', 'Blue', 'Green',
#        'Blue', 'Yellow', 'Yellow', 'Yellow', 'Blue', 'Yellow', 'grey',
#        'Green', 'Blue', 'Yellow', 'Green', 'Blue', 'Green', 'grey',
#        'Blue', 'Yellow', 'Red', 'Yellow', 'Blue', 'Yellow', 'Red', 'Red',
#        'Red', 'Yellow', 'Blue', 'Yellow', 'Red', 'grey', 'Red', 'brown',
#        'Red', 'brown', 'Blue', 'Yellow', 'Blue', 'Yellow', 'brown', 'Red',
#        'Red', 'Red', 'Yellow', 'Red', 'Blue', 'Blue', 'Red', 'grey',
#        'Yellow', 'grey', 'brown', 'Red', 'grey', 'Yellow', 'brown',
#        'Yellow', 'grey', 'brown', 'Green', 'brown', 'Yellow', 'Red',
#        'Red', 'Red', 'brown', 'brown', 'Green', 'Red', 'grey', 'Green',
#        'brown', 'brown', 'Yellow', 'Green', 'Red', 'Red', 'grey',
#        'Yellow', 'Yellow', 'Green', 'brown', 'brown', 'Red', 'Red',
#        'Green', 'Blue', 'Red', 'Yellow', 'brown', 'Green', 'Green',
#        'grey', 'Red', 'brown', 'Red', 'Yellow', 'Blue', 'Yellow', 'Blue',
#        'grey', 'Yellow', 'brown', 'brown', 'Yellow', 'Red', 'Yellow',
#        'Red', 'grey', 'Blue', 'Yellow', 'brown', 'brown', 'grey', 'Red',
#        'Blue', 'Yellow', 'Yellow', 'Green', 'brown', 'Yellow', 'grey',
#        'brown', 'brown', 'Yellow', 'Yellow', 'Green', 'Green', 'Green',
#        'Yellow', 'Blue', 'Blue', 'grey', 'Yellow', 'Green', 'Blue',
#        'Yellow', 'brown', 'brown', 'brown', 'Green', 'grey', 'Blue',
#        'Blue', 'Red', 'Green', 'brown', 'Red', 'grey', 'Red', 'Yellow',
#        'Blue', 'brown', 'brown', 'Red', 'Red', 'brown', 'Green', 'Green',
#        'Red', 'Yellow', 'Red', 'Yellow', 'Red', 'grey', 'grey', 'Red',
#        'Green', 'Yellow', 'grey', 'Yellow', 'Blue', 'brown', 'Green',
#        'Green', 'Blue', 'Green', 'brown', 'grey', 'brown', 'Blue',
#        'brown', 'brown', 'grey', 'grey', 'brown', 'brown', 'Blue',
#        'Yellow', 'brown', 'Yellow', 'Green', 'Blue', 'grey', 'Yellow',
#        'Yellow', 'Green', 'Green', 'brown', 'brown', 'Green', 'Green',
#        'Blue', 'Red', 'Yellow', 'Green', 'grey', 'Yellow', 'Green',
#        'Green', 'Blue', 'Red', 'Red', 'Blue', 'grey', 'Red', 'grey',
#        'Yellow', 'Yellow', 'Red', 'Red', 'Yellow', 'brown', 'Yellow',
#        'Red', 'Yellow', 'Red', 'brown', 'Blue', 'Green', 'Red', 'grey',
#        'Red', 'Yellow', 'grey', 'grey', 'Green', 'Red', 'Blue', 'grey',
#        'grey', 'Blue', 'grey', 'Yellow', 'Blue', 'Yellow', 'Red', 'brown',
#        'brown', 'brown', 'Red', 'Red', 'brown', 'Yellow', 'grey', 'grey',
#        'brown', 'Blue', 'Blue', 'grey', 'Green', 'Yellow', 'Yellow',
#        'Yellow', 'Green', 'Blue', 'brown', 'Blue', 'Yellow', 'brown',
#        'Blue', 'Yellow', 'grey', 'grey', 'Blue', 'brown', 'Green', 'Blue',
#        'brown', 'Red', 'Yellow', 'Red', 'Blue', 'grey', 'Yellow', 'Blue',
#        'Green', 'Blue', 'Green', 'grey', 'brown', 'Green', 'Red', 'brown',
#        'Red', 'Red', 'Red', 'Red', 'Green', 'Red', 'Yellow', 'Green',
#        'grey', 'Green', 'Blue', 'grey', 'Red', 'Red', 'Blue', 'brown',
#        'Red', 'grey', 'grey', 'grey', 'Green', 'Green', 'grey', 'Green',
#        'brown', 'Green', 'Yellow', 'brown', 'Green', 'Yellow', 'brown',
#        'Yellow', 'Green', 'Green', 'Green', 'Red', 'Yellow', 'Red',
#        'grey', 'Green', 'grey', 'brown', 'Red', 'Yellow', 'Blue', 'Green',
#        'grey', 'grey', 'grey', 'Red', 'Red', 'Blue', 'brown', 'Red',
#        'Yellow', 'Yellow', 'grey', 'Green', 'grey', 'Yellow', 'Yellow',
#        'Yellow', 'grey', 'Blue', 'Green', 'Blue', 'Blue', 'Green',
#        'Yellow', 'Yellow', 'grey', 'grey', 'Blue', 'Green', 'Green',
#        'Red', 'Red', 'Blue', 'grey', 'Yellow', 'brown', 'Yellow', 'Blue',
#        'Green', 'Red', 'grey', 'Green', 'grey', 'grey', 'Blue', 'Red',
#        'Red', 'brown', 'Yellow', 'Green', 'brown', 'brown', 'Green',
#        'brown', 'Red', 'grey', 'Yellow', 'brown', 'Yellow', 'grey',
#        'Yellow', 'grey', 'Yellow', 'Red', 'brown', 'Yellow', 'Yellow',
#        'Green', 'Yellow', 'brown', 'brown', 'grey', 'Red', 'Yellow',
#        'Red', 'Red', 'Yellow', 'Green', 'Blue', 'Yellow', 'Blue',
#        'Yellow', 'Red', 'Yellow', 'Blue', 'Red', 'Yellow', 'Green',
#        'grey', 'Yellow', 'Green', 'Blue', 'brown', 'Green', 'grey',
#        'Green', 'brown', 'Yellow', 'Green', 'Yellow', 'Blue', 'grey',
#        'brown', 'Green', 'grey', 'Green', 'grey', 'Green', 'Blue',
#        'brown', 'brown', 'Blue', 'Yellow', 'Green', 'Blue', 'Blue',
#        'grey', 'Blue', 'Blue', 'Yellow', 'Red', 'brown', 'grey', 'Blue',
#        'Red', 'Red', 'Blue', 'Yellow', 'brown', 'brown', 'brown', 'Green',
#        'brown', 'Yellow', 'Blue', 'grey', 'Green', 'Green', 'Blue',
#        'Blue', 'grey', 'brown', 'Yellow', 'grey', 'brown', 'Blue', 'grey',
#        'brown', 'Blue', 'Green', 'grey', 'Red', 'Green', 'Red', 'Blue',
#        'Red', 'Yellow', 'brown', 'Blue', 'Red', 'Blue', 'Yellow', 'Red',
#        'Red', 'Green', 'Red', 'brown', 'Red', 'Blue', 'Yellow', 'grey',
#        'brown', 'Yellow', 'Yellow', 'Red', 'grey', 'grey', 'Yellow',
#        'Blue', 'grey', 'grey', 'brown', 'Yellow', 'brown', 'brown',
#        'Green', 'grey', 'brown', 'brown', 'Yellow', 'Green', 'Yellow',
#        'brown', 'Yellow', 'Blue', 'Red', 'Green', 'brown', 'brown',
#        'brown', 'Red', 'Green', 'brown', 'Green', 'brown', 'grey', 'Blue',
#        'Blue', 'Yellow', 'Red', 'brown', 'brown', 'Yellow', 'Blue',
#        'Yellow', 'Blue', 'Blue', 'Green', 'Yellow', 'Green', 'Yellow',
#        'brown', 'Blue', 'brown', 'Blue', 'grey', 'Green', 'brown', 'Red',
#        'Yellow', 'brown', 'Red', 'grey', 'Blue', 'Green', 'Red', 'Green',
#        'Blue', 'Green', 'Green', 'brown', 'Yellow', 'Red', 'grey',
#        'Green', 'Green', 'brown', 'grey', 'Red', 'Blue', 'Yellow', 'grey',
#        'Green', 'Blue', 'Yellow', 'grey', 'Green', 'Red', 'grey', 'Green',
#        'Blue', 'grey', 'Yellow', 'Red', 'grey', 'brown', 'grey', 'brown',
#        'Red', 'brown', 'Blue', 'Yellow', 'Green', 'Blue', 'Green',
#        'brown', 'Yellow', 'Blue', 'grey', 'Blue', 'Green', 'grey', 'Red',
#        'Blue', 'Blue', 'grey', 'Blue', 'grey', 'Red', 'Blue', 'Green',
#        'Blue', 'grey', 'grey', 'Green', 'Green', 'grey', 'brown', 'grey',
#        'Blue', 'grey', 'Green', 'Blue', 'grey', 'Red', 'Green', 'brown',
#        'Red', 'Blue', 'Green', 'Blue', 'Yellow', 'Green', 'Blue', 'Red',
#        'Blue', 'grey', 'grey', 'Red', 'Blue', 'Green', 'Red', 'Blue',
#        'Yellow', 'grey', 'Red', 'Blue', 'Yellow', 'grey', 'Yellow',
#        'brown', 'Red', 'Blue', 'Yellow', 'Yellow', 'Yellow', 'Green',
#        'Yellow', 'Blue', 'Blue', 'Blue', 'grey', 'Yellow', 'Red', 'grey',
#        'brown', 'Green', 'Blue', 'Green', 'grey', 'Green', 'grey',
#        'brown', 'Green', 'Blue', 'brown', 'Yellow', 'Blue', 'brown',
#        'Blue', 'Blue', 'Yellow', 'Blue', 'grey', 'brown', 'Green',
#        'Yellow', 'Red', 'brown', 'grey', 'brown', 'Yellow', 'Green',
#        'Yellow', 'grey', 'grey', 'brown', 'Red', 'Blue', 'Green', 'brown',
#        'grey', 'grey', 'Green', 'brown', 'grey', 'Red', 'Red', 'Blue',
#        'brown', 'brown', 'brown', 'Yellow', 'Green', 'Red', 'Red', 'Red',
#        'Red', 'Blue', 'grey', 'brown', 'Red', 'brown', 'Blue', 'Yellow',
#        'brown', 'grey', 'Yellow', 'grey', 'brown', 'grey', 'grey', 'Blue',
#        'Green', 'Yellow', 'grey', 'grey', 'Red', 'brown', 'Red', 'Blue',
#        'grey', 'Yellow', 'brown', 'Yellow', 'Red', 'Red', 'Green', 'grey',
#        'grey', 'brown', 'Red', 'Red', 'Red', 'Green', 'brown', 'Green',
#        'Green', 'grey', 'Green', 'grey', 'Red', 'grey', 'Yellow', 'brown',
#        'Blue', 'Red', 'Yellow', 'Blue', 'Yellow', 'Blue', 'Blue', 'Green',
#        'Yellow', 'brown', 'Yellow', 'Red', 'brown', 'grey', 'brown',
#        'brown', 'brown', 'Yellow', 'Yellow', 'Red', 'Red', 'Green',
#        'brown', 'grey', 'grey', 'Green', 'brown', 'brown', 'brown', 'Red',
#        'Red', 'Red', 'Yellow', 'grey', 'grey', 'Blue', 'Blue', 'Yellow',
#        'Yellow', 'grey', 'brown', 'Blue', 'brown', 'Green', 'Red', 'grey',
#        'Green', 'Yellow', 'Red', 'Yellow', 'Blue', 'brown', 'Green',
#        'brown', 'Red', 'Red', 'Yellow', 'brown', 'grey', 'Green', 'Red',
#        'Red', 'brown', 'Blue', 'Green', 'Green', 'Red', 'brown', 'Green',
#        'Green', 'Red', 'Red', 'Yellow', 'brown', 'Yellow', 'brown',
#        'Yellow', 'Yellow', 'Green', 'Blue', 'Red', 'Red', 'grey', 'Blue',
#        'brown', 'Blue', 'Red', 'Blue', 'brown', 'grey', 'Green', 'brown',
#        'Yellow', 'grey', 'brown', 'brown', 'Yellow', 'Red'], dtype='<U6')

# %%
dataframe=pd.DataFrame(nominal_data, columns=['colors'])
dataframe
# Out:
#      colors
# 0      grey
# 1     brown
# 2       Red
# 3    Yellow
# 4    Yellow
# ..      ...
# 995    grey
# 996   brown
# 997   brown
# 998  Yellow
# 999     Red
#
# [1000 rows x 1 columns]

# %% [markdown]
# # Data Creation of ordinal Column named "satisfaction_level"

# %%
satisfaction_level=['low','medium','high']
ordinal_data= np.random.choice(satisfaction_level,size=num_samples)
